# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
apples = 60
oranges = 40
total = apples + oranges

p = apples / total
q = oranges / total
p, q
# Out:
# (0.6, 0.4)

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 2. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
p1 = p ** 5
print('1. The probability that the first 5 fruits are all apples is', p1)
p2 = p ** 5 * q ** 15
print('2. The probability that the first 5 fruits are all apples and the next 15 fruits are all oranges is', p2)
# Out:
# 1. The probability that the first 5 fruits are all apples is 0.07775999999999998
# 2. The probability that the first 5 fruits are all apples and the next 15 fruits are all oranges is 8.349416423424006e-08

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
from math import comb

n = 20  # total fruits picked
k = 5   # number of apples
p = 0.6  # probability of picking an apple
q = 0.4  # probability of picking an orange (1 - p)

# Binomial probability
prob_5_apples_15_oranges = comb(n, k) * (p ** k) * (q ** (n - k))

print(f"The probability that the sample contains exactly 5 apples and 15 oranges is: {prob_5_apples_15_oranges:.8f}")
# Out:
# The probability that the sample contains exactly 5 apples and 15 oranges is: 0.00129449

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
# Calculate the cumulative probability for k = 0 to 4
cdf_less_than_5_apples = sum(comb(n, k) * (p ** k) * (q ** (n - k)) for k in range(5))

print(f"The probability that less than 5 fruits picked are apples is: {cdf_less_than_5_apples:.8f}")
# Out:
# The probability that less than 5 fruits picked are apples is: 0.00031703

# %% [markdown]
# **Plot the PDF (probability distributiom function) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
x = np.arange(0, n+1)
binomial_probs = [comb(n, k) * (p ** k) * (q ** (n - k)) for k in x]

plt.figure(figsize=(10, 6))
plt.bar(x, binomial_probs, color='blue', alpha=0.7)
plt.xlabel('Number of Apples (k)')
plt.ylabel('Probability')
plt.title('Binomial Distribution PDF (n=20, p=0.6)')
plt.show()

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
lambda_value = 2.3  # average number of goals
k = 5  # number of goals we want the probability for

# Calculate the Poisson probability
poisson_prob = (math.exp(-lambda_value) * (lambda_value ** k)) / math.factorial(k)

print(f"The probability that the number of goals scored in a match is {k} is: {poisson_prob:.8f}")
# Out:
# The probability that the number of goals scored in a match is 5 is: 0.05377503

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
# Calculate Poisson probabilities for k = 0 to 10
x = np.arange(0, 11)
poisson_probs = [(math.exp(-lambda_value) * (lambda_value ** k) / math.factorial(k)) for k in x]

# Plot the Poisson probability distribution
plt.figure(figsize=(10, 6))
plt.bar(x, poisson_probs, color='blue', alpha=0.7)
plt.xlabel('Number of Goals (k)')
plt.ylabel('Probability')
plt.title('Poisson Distribution for Goals Scored in a Match (λ=2.3)')
plt.show()
